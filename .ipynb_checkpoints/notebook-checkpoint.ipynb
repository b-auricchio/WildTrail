# %%
import numpy as np
import matplotlib.pyplot as plt

from models.target import Target, get_jacobian_F
from models.drone import get_jacobian_H, Drone, pos2z, z2pos
from filters.kalman import ExtendedKalmanFilter
from utils.plotting import animation_function

np.random.seed(1000)

N = 1000 # number of time steps
Q_model = np.diag([0, 0, 0.3, 0.6])**2 # process noise
x0 = np.array([0, 0, 0, 1]) # initial state [x, y, alpha, velocity]'

R = np.diag([0.1, 0.1])**2 # measurement noise
P0 = np.eye(4)*10 # initial covariance

# get track 
target = Target(x0) # x,y,a = 0, v = 1
dt = 0.1
track = [target.update_states(dt, Q_model) for _ in range(N)]

# get sensor measurements
drone = Drone(np.array([-20, -1, 100]))

Q = Q_model*3 # kalman filter process noise 3x larger than actual process noise
kf = ExtendedKalmanFilter(x0, P0, Q_model, R)

for t in track:
    drone.move_to(drone.get_pos()+np.array([0.13, 0.2, 0]))
    z = drone.sense(t, R.diagonal())
    kf.predict(target.transition, get_jacobian_F, dt)
    kf.update(z, drone.get_pos(), pos2z, get_jacobian_H)

# %%
# plot residuals
track = np.array(track)
xs = np.array(kf.saver.x)
error = np.array([np.linalg.norm(x-t) for x, t in zip(xs[:,:2], track[:,:2])])
range = np.array(kf.saver.range)

plt.figure()
plt.plot(range, error)

plt.ylabel('error')
plt.xlabel('range')

plt.show()

# %% [markdown]
# Tutorial

# %%
import ipywidgets as widgets

# %%
# %matplotlib widget
x = np.linspace(0, 2*np.pi, 1000)
def sine_wave(t=0):
    y = np.sin(x+0.1*t)
    plt.plot(x, y)

# %%
widgets.interact(sine_wave, t=widgets.Play(min=0, max=20))
# Out:
# interactive(children=(Play(value=0, description='t', max=20), Output()), _dom_classes=('widget-interact',))
# <function __main__.sine_wave(t=0)>
